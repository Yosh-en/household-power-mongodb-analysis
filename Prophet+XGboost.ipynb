# %%
#DATA INGESTION

#Importing the dataset and printing the first 5 rows using head func
import pandas as pd
df = pd.read_csv(
    r"C:\Users\yoshi\Downloads\PandasAssignment\household_power_consumption.txt",
    sep=";"
)
# Out:
# C:\Users\yoshi\AppData\Local\Temp\ipykernel_13764\3863594366.py:5: DtypeWarning: Columns (2,3,4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(

# %%
#Adding timestamp 
#Initially only used DataFrame methods then used datetime func to turn into objects so python can undertsand it 
#Also learnt formatting here

df["timestamp"] = pd.to_datetime(df["Date"] + " " + df["Time"],format="%d/%m/%Y %H:%M:%S")
print(df.head())
# Out:
#          Date      Time Global_active_power Global_reactive_power  Voltage  \
# 0  16/12/2006  17:24:00               4.216                 0.418  234.840
# 1  16/12/2006  17:25:00               5.360                 0.436  233.630
# 2  16/12/2006  17:26:00               5.374                 0.498  233.290
# 3  16/12/2006  17:27:00               5.388                 0.502  233.740
# 4  16/12/2006  17:28:00               3.666                 0.528  235.680
#
#   Global_intensity Sub_metering_1 Sub_metering_2  Sub_metering_3  \
# 0           18.400          0.000          1.000            17.0
# 1           23.000          0.000          1.000            16.0
# 2           23.000          0.000          2.000            17.0
# 3           23.000          0.000          1.000            17.0
# 4           15.800          0.000          1.000            17.0
#
#             timestamp
# 0 2006-12-16 17:24:00
# 1 2006-12-16 17:25:00
# 2 2006-12-16 17:26:00
# 3 2006-12-16 17:27:00
# 4 2006-12-16 17:28:00

# %%
#before removing NULL vals, checking missing mixed values as per wrning initially
print((df == "?").sum())
# Out:
# Date                         0
# Time                         0
# Global_active_power      25979
# Global_reactive_power    25979
# Voltage                  25979
# Global_intensity         25979
# Sub_metering_1           25979
# Sub_metering_2           25979
# Sub_metering_3               0
# timestamp                    0
# dtype: int64

# %%
#Checking data set size to verify after cleaning up
print(df.shape)
# Out:
# (2075259, 10)

# %%
df = df.replace("?", pd.NA) #turn missing to Null
df = df.dropna()

print(df.shape)  #check if we got rid of the null vals
# Out:
# (2049280, 10)

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2049280 entries, 0 to 2075258
# Data columns (total 10 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    object
#  3   Global_reactive_power  object
#  4   Voltage                object
#  5   Global_intensity       object
#  6   Sub_metering_1         object
#  7   Sub_metering_2         object
#  8   Sub_metering_3         float64
#  9   timestamp              datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), object(8)
# memory usage: 172.0+ MB
# None

# %%
#Had to fix data types to run aggregate funcs more easily
df["Global_active_power"] = pd.to_numeric(df["Global_active_power"])
df["Global_reactive_power"] = pd.to_numeric(df["Global_reactive_power"])
df["Voltage"] = pd.to_numeric(df["Voltage"])
df["Global_intensity"] = pd.to_numeric(df["Global_intensity"])
df["Sub_metering_1"] = pd.to_numeric(df["Sub_metering_1"])
df["Sub_metering_2"] = pd.to_numeric(df["Sub_metering_2"])

# %%
#verifying the data types
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2049280 entries, 0 to 2075258
# Data columns (total 10 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Date                   object
#  1   Time                   object
#  2   Global_active_power    float64
#  3   Global_reactive_power  float64
#  4   Voltage                float64
#  5   Global_intensity       float64
#  6   Sub_metering_1         float64
#  7   Sub_metering_2         float64
#  8   Sub_metering_3         float64
#  9   timestamp              datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), object(2)
# memory usage: 172.0+ MB
# None

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\yoshi\anaconda3\envs\ml_env\python.exe

# %%
import sys
# !{sys.executable} -m pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\yoshi\anaconda3\envs\ml_env\lib\site-packages (4.17.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\yoshi\anaconda3\envs\ml_env\lib\site-packages (from pymongo) (2.8.0)

# %%
import pymongo
print(pymongo.__version__)
# Out:
# 4.17.0

# %%
from pymongo import MongoClient
client = MongoClient("mongodb://localhost:27017")
print(client.list_database_names())
# Out:
# ['admin', 'config', 'local', 'power_db']

# %%
db = client["power_db"]
collection = db["power_consumption"]
print(collection)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'power_db'), 'power_consumption')

# %%
#new dataframe with 5 rows only rn
sample_df = df.head(5)

# %%
records = sample_df.to_dict("records")

# %%
#Convert to dictionary to be more compatibke to mongodb
records = sample_df.to_dict("records")

# %%
#Inserting into mongodb
result = collection.insert_many(records)

# %%
#Verifying if the insertion worked or nah
print(len(result.inserted_ids))
# Out:
# 5

# %%
peak_row = df.loc[df["Global_active_power"].idxmax()]

print(peak_row["timestamp"])
print(peak_row["Global_active_power"])
# Out:
# 2009-02-22 17:09:00
# 11.122

# %%
print(collection.count_documents({}))
# Out:
# 11346430

# %%
#inserting the entire dataset/dataframe in batches
batch_size = 10000

for start in range(0, len(df), batch_size):
    batch = df.iloc[start:start + batch_size]
    records = batch.to_dict("records")
    collection.insert_many(records)
    print("Inserted:", start + len(batch))
# Out:
# Inserted: 10000
# Inserted: 20000
# Inserted: 30000
# Inserted: 40000
# Inserted: 50000
# Inserted: 60000
# Inserted: 70000
# Inserted: 80000
# Inserted: 90000
# Inserted: 100000
# Inserted: 110000
# Inserted: 120000
# Inserted: 130000
# Inserted: 140000
# Inserted: 150000
# Inserted: 160000
# Inserted: 170000
# Inserted: 180000
# Inserted: 190000
# Inserted: 200000
# Inserted: 210000
# Inserted: 220000
# Inserted: 230000
# Inserted: 240000
# Inserted: 250000
# Inserted: 260000
# Inserted: 270000
# Inserted: 280000
# Inserted: 290000
# Inserted: 300000
# Inserted: 310000
# Inserted: 320000
# Inserted: 330000
# Inserted: 340000
# Inserted: 350000
# Inserted: 360000
# Inserted: 370000
# Inserted: 380000
# Inserted: 390000
# Inserted: 400000
# Inserted: 410000
# Inserted: 420000
# Inserted: 430000
# Inserted: 440000
# Inserted: 450000
# Inserted: 460000
# Inserted: 470000
# Inserted: 480000
# Inserted: 490000
# Inserted: 500000
# Inserted: 510000
# Inserted: 520000
# Inserted: 530000
# Inserted: 540000
# Inserted: 550000
# Inserted: 560000
# Inserted: 570000
# Inserted: 580000
# Inserted: 590000
# Inserted: 600000
# Inserted: 610000
# Inserted: 620000
# Inserted: 630000
# Inserted: 640000
# Inserted: 650000
# Inserted: 660000
# Inserted: 670000
# Inserted: 680000
# Inserted: 690000
# Inserted: 700000
# Inserted: 710000
# Inserted: 720000
# Inserted: 730000
# Inserted: 740000
# Inserted: 750000
# Inserted: 760000
# Inserted: 770000
# Inserted: 780000
# Inserted: 790000
# Inserted: 800000
# Inserted: 810000
# Inserted: 820000
# Inserted: 830000
# Inserted: 840000
# Inserted: 850000
# Inserted: 860000
# Inserted: 870000
# Inserted: 880000
# Inserted: 890000
# Inserted: 900000
# Inserted: 910000
# Inserted: 920000
# Inserted: 930000
# Inserted: 940000
# Inserted: 950000
# Inserted: 960000
# Inserted: 970000
# Inserted: 980000
# Inserted: 990000
# Inserted: 1000000
# Inserted: 1010000
# Inserted: 1020000
# Inserted: 1030000
# Inserted: 1040000
# Inserted: 1050000
# Inserted: 1060000
# Inserted: 1070000
# Inserted: 1080000
# Inserted: 1090000
# Inserted: 1100000
# Inserted: 1110000
# Inserted: 1120000
# Inserted: 1130000
# Inserted: 1140000
# Inserted: 1150000
# Inserted: 1160000
# Inserted: 1170000
# Inserted: 1180000
# Inserted: 1190000
# Inserted: 1200000
# Inserted: 1210000
# Inserted: 1220000
# Inserted: 1230000
# Inserted: 1240000
# Inserted: 1250000
# Inserted: 1260000
# Inserted: 1270000
# Inserted: 1280000
# Inserted: 1290000
# Inserted: 1300000
# Inserted: 1310000
# Inserted: 1320000
# Inserted: 1330000
# Inserted: 1340000
# Inserted: 1350000
# Inserted: 1360000
# Inserted: 1370000
# Inserted: 1380000
# Inserted: 1390000
# Inserted: 1400000
# Inserted: 1410000
# Inserted: 1420000
# Inserted: 1430000
# Inserted: 1440000
# Inserted: 1450000
# Inserted: 1460000
# Inserted: 1470000
# Inserted: 1480000
# Inserted: 1490000
# Inserted: 1500000
# Inserted: 1510000
# Inserted: 1520000
# Inserted: 1530000
# Inserted: 1540000
# Inserted: 1550000
# Inserted: 1560000
# Inserted: 1570000
# Inserted: 1580000
# Inserted: 1590000
# Inserted: 1600000
# Inserted: 1610000
# Inserted: 1620000
# Inserted: 1630000
# Inserted: 1640000
# Inserted: 1650000
# Inserted: 1660000
# Inserted: 1670000
# Inserted: 1680000
# Inserted: 1690000
# Inserted: 1700000
# Inserted: 1710000
# Inserted: 1720000
# Inserted: 1730000
# Inserted: 1740000
# Inserted: 1750000
# Inserted: 1760000
# Inserted: 1770000
# Inserted: 1780000
# Inserted: 1790000
# Inserted: 1800000
# Inserted: 1810000
# Inserted: 1820000
# Inserted: 1830000
# Inserted: 1840000
# Inserted: 1850000
# Inserted: 1860000
# Inserted: 1870000
# Inserted: 1880000
# Inserted: 1890000
# Inserted: 1900000
# Inserted: 1910000
# Inserted: 1920000
# Inserted: 1930000
# Inserted: 1940000
# Inserted: 1950000
# Inserted: 1960000
# Inserted: 1970000
# Inserted: 1980000
# Inserted: 1990000
# Inserted: 2000000
# Inserted: 2010000
# Inserted: 2020000
# Inserted: 2030000
# Inserted: 2040000
# Inserted: 2049280

# %%
#checking insertion succes
print(collection.count_documents({}))
# Out:
# 13395710

# %%
#PART 2
#finding the peak consumption
peak = collection.find_one(
    sort=[("Global_active_power", -1)]
)

print("Timestamp:", peak["timestamp"])
print("Power:", peak["Global_active_power"])
# Out:
# Timestamp: 2009-02-22 17:09:00
# Power: 11.122

# %%
#fetch all data points for February 2nd, 2008.
from datetime import datetime

start = datetime(2008, 2, 2)
end = datetime(2008, 2, 3)
records = list(
    collection.find(
        {
            "timestamp": {
                "$gte": start,
                "$lt": end
            }
        }
    )
)

print("Records found:", len(records))

#Since the original dataset contained missing values were removed , 
#the count is slightly lower than the USUAL 1440 minute-level measurements for a  day.
# Out:
# Records found: 10073

# %%
#Finding records where global_active_power>7, using query by val
records = list(
    collection.find(
        {
            "Global_active_power": {
                "$gt": 7
            }
        }
    )
)
print("Count:", len(records))
# Out:
# Count: 10940

# %%
#Basic statistics
pipeline = [
    {
        "$group": {
            "_id": None,

            "average_power": {
                "$avg": "$Global_active_power"
            },

            "minimum_power": {
                "$min": "$Global_active_power"
            },

            "maximum_power": {
                "$max": "$Global_active_power"
            }
        }
    }
]

result = list(collection.aggregate(pipeline))
print(result)
# Out:
# [{'_id': None, 'average_power': 1.0938310694991158, 'minimum_power': 0.076, 'maximum_power': 11.122}]

# %%
#Monthly consumption since of each month in 2008
from datetime import datetime

pipeline = [

    {
        "$match": {
            "timestamp": {
                "$gte": datetime(2008, 1, 1),
                "$lt": datetime(2009, 1, 1)
            }
        }
    },

    {
        "$group": {
            "_id": {
                "$month": "$timestamp"
            },

            "total_power": {
                "$sum": "$Global_active_power"
            }
        }
    },

    {
        "$sort": {
            "_id": 1
        }
    }

]

result = list(collection.aggregate(pipeline))

for month in result:
    print(month)
# Out:
# {'_id': 1, 'total_power': 456185.674}
# {'_id': 2, 'total_power': 345317.504}
# {'_id': 3, 'total_power': 389134.158}
# {'_id': 4, 'total_power': 337469.944}
# {'_id': 5, 'total_power': 320053.02}
# {'_id': 6, 'total_power': 300607.804}
# {'_id': 7, 'total_power': 248341.926}
# {'_id': 8, 'total_power': 86393.16}
# {'_id': 9, 'total_power': 298674.544}
# {'_id': 10, 'total_power': 354875.22}
# {'_id': 11, 'total_power': 419361.32}
# {'_id': 12, 'total_power': 397837.384}

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# %%
#target column
data = df[['Global_active_power']].values  # shape (n, 1)

# %%
data = data[-5000:]

# %%
#Scale
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)

# %%
#Train/test split (65/35)
training_size = int(len(scaled_data) * 0.65)
train_data = scaled_data[0:training_size]
test_data = scaled_data[training_size:]

# %%
#Sliding window
def create_dataset(dataset, time_step=100):
    X, y = [], []
    for i in range(len(dataset) - time_step - 1):
        X.append(dataset[i:(i+time_step), 0])
        y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(y)

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# %%
#Reshape for LSTM 
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
#Stacked LSTM model (same architecture as AAPL)
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(time_step, 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error', optimizer='adam')
# Out:
# C:\Users\yoshi\anaconda3\envs\ml_env\lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
#train train train
model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=5, batch_size=64, verbose=1)
# Out:
# Epoch 1/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 26s 349ms/step - loss: 0.0129 - val_loss: 0.0058
# Epoch 2/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 15s 303ms/step - loss: 0.0073 - val_loss: 0.0036
# Epoch 3/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 327ms/step - loss: 0.0050 - val_loss: 0.0027
# Epoch 4/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 321ms/step - loss: 0.0044 - val_loss: 0.0024
# Epoch 5/5
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 16s 323ms/step - loss: 0.0038 - val_loss: 0.0022

# %%
#predict
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)
# Out:
# 99/99 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 4s 80ms/step

# %%
#Tranforming back to raw data
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train_actual = scaler.inverse_transform(y_train.reshape(-1,1))
y_test_actual = scaler.inverse_transform(y_test.reshape(-1,1))

# %%
# Plot predicted vs actual
plt.figure(figsize=(12,6))
plt.plot(y_test_actual, label='Actual')
plt.plot(test_predict, label='Predicted')
plt.legend()
plt.title('Global Active Power: Actual vs Predicted')
plt.xlabel('Time steps')
plt.ylabel('kW')
plt.show()

# %%
#PROPHET
from prophet import Prophet
import pandas as pd
import matplotlib.pyplot as plt

# %%
#prophet's 2 cols
prophet_df = df[['timestamp', 'Global_active_power']].copy()
prophet_df.columns = ['ds', 'y']
prophet_df['ds'] = pd.to_datetime(prophet_df['ds'])

# %%
#subsampling like we did in lstm above
prophet_df = prophet_df.tail(5000)

# %%
#train/test split
train_size = int(len(prophet_df) * 0.65)
train = prophet_df[:train_size]
test = prophet_df[train_size:]

# %%
# Fit
model = Prophet()
model.fit(train)
# Out:
# 15:55:46 - cmdstanpy - INFO - Chain [1] start processing
# 15:55:48 - cmdstanpy - INFO - Chain [1] done processing

# %%
#forecast for the length of the test set
future = model.make_future_dataframe(periods=len(test), freq='min')  # adjust freq to data's interval
forecast = model.predict(future)

# %%
# Plot
fig = model.plot(forecast)
plt.show()

# %%
fig2 = model.plot_components(forecast)
plt.show()

# %%
import matplotlib.pyplot as plt

merged = forecast[['ds','yhat']].merge(test, on='ds')
plt.figure(figsize=(12,6))
plt.plot(merged['ds'], merged['y'], label='Actual')
plt.plot(merged['ds'], merged['yhat'], label='Predicted')
plt.legend()
plt.show()

# %%
#XGBOOST
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from xgboost import XGBRegressor

# %%
data = df[['timestamp', 'Global_active_power']].copy()
data['timestamp'] = pd.to_datetime(data['timestamp'])
data = data.set_index('timestamp')

# %%
#subsample-same as before
data = data.tail(5000)

# %%
#Feature engineering
data['lag_1'] = data['Global_active_power'].shift(1)
data['lag_24'] = data['Global_active_power'].shift(24)
data['rolling_mean_24'] = data['Global_active_power'].rolling(24).mean()
data['hour'] = data.index.hour
data['day_of_week'] = data.index.dayofweek

# %%
data = data.dropna()#dropping rows from shifting

# %%
train_size = int(len(data) * 0.65)
train = data[:train_size]
test = data[train_size:]

# %%
features = ['lag_1', 'lag_24', 'rolling_mean_24', 'hour', 'day_of_week']
X_train, y_train = train[features], train['Global_active_power']
X_test, y_test = test[features], test['Global_active_power']

# %%
#train
model = XGBRegressor(n_estimators=100, max_depth=5, learning_rate=0.1)
model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=100,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
#Predict
predictions = model.predict(X_test)

# %%
#here comes the plot
plt.figure(figsize=(12,6))
plt.plot(y_test.values, label='Actual')
plt.plot(predictions, label='Predicted')
plt.legend()
plt.title('XGBoost: Actual vs Predicted')
plt.xlabel('Time steps')
plt.ylabel('kW')
plt.show()

# %%
#feature importance(uselful if we end up choosing this model)
import xgboost as xgb
xgb.plot_importance(model)
plt.show()
